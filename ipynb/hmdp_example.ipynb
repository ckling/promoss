# %%
# %run 'hmdp.ipynb'

#directory of meta.txt and corpus.txt
directory = "/home/c/work/topicmodels/food_test/";
#the first value in meta.txt are Geographical coordinates
#and we want to detect 1000 clusters
meta_params = "G(1000)";

#construct HMDP class
hmdp = HMDP(directory, meta_params);
#set max. topics which can be detected
hmdp.T = 25;
#we only keep words which appear at least the given number of times
hmdp.MIN_DICT_WORDS = 2;
#run model for a given number of iterations
hmdp.RUNS = 100;

#run model
hmdp.run();

hmdp.map_from_JSON();
# Out:
# Running HMDP topic model... (please wait)
# Clustering metadata...
# G
# Geographical clustering step 0 (Likelihood: 1.0)
# Geographical clustering step 1 (Likelihood: -1.3547243107482402E9)
# Geographical clustering step 2 (Likelihood: -4.133415625883352E22)
# Geographical clustering step 3 (Likelihood: -4.167260632884519E22)
# Creating dictionary...
# Initialising parameters...
# Reading groups...
# Processing documents...
# ...................................................
# Estimating topics...
# /home/c/work/topicmodels/food_test/ run 0 (Topics 0 alpha_0 1.0 alpha_1 1.0 beta_0 0.01 gamma 1.0 delta 1.0 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 1 (Topics 25 alpha_0 1.0 alpha_1 1.0 beta_0 0.01 gamma 1.0 delta 1.0 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 2 (Topics 24 alpha_0 5.673077183599325 alpha_1 1.0 beta_0 0.03858488846186706 gamma 1.0 delta 0.5754704370422491 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 3 (Topics 24 alpha_0 10.913343417199696 alpha_1 1.0 beta_0 0.04270967118183278 gamma 2.28171696418355 delta 0.48163572818137446 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 4 (Topics 24 alpha_0 15.781118547749687 alpha_1 1.0 beta_0 0.03816347177828541 gamma 2.519677231914928 delta 0.43042643444552275 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 5 (Topics 23 alpha_0 20.082027942063515 alpha_1 1.0 beta_0 0.03256840591059579 gamma 2.5289015607744467 delta 0.39611038158971346 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 6 (Topics 21 alpha_0 23.65069348654802 alpha_1 1.0 beta_0 0.027840577993925687 gamma 2.519256712576396 delta 0.3704201259728913 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 7 (Topics 20 alpha_0 26.373282358163205 alpha_1 1.0 beta_0 0.02420025674626484 gamma 2.5099815020396354 delta 0.34999161501666015 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 8 (Topics 19 alpha_0 28.212331030305936 alpha_1 1.0 beta_0 0.020958796351117717 gamma 2.5093706884261646 delta 0.33284122573866254 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 9 (Topics 18 alpha_0 29.190958557597213 alpha_1 1.0 beta_0 0.01802095864026988 gamma 2.5140091272427476 delta 0.31824667784854965 epsilon 1.0
# ...................................................
# Storing variables...
# /home/c/work/topicmodels/food_test/ run 10 (Topics 17 alpha_0 29.381513160987268 alpha_1 1.0 beta_0 0.015200769768407226 gamma 2.5229708402955957 delta 0.30548003720416905 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 11 (Topics 15 alpha_0 28.884256330184048 alpha_1 1.0 beta_0 0.012226552881163415 gamma 2.533442387127516 delta 0.2941154178289796 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 12 (Topics 15 alpha_0 27.805218038636184 alpha_1 1.0 beta_0 0.009445114399563677 gamma 2.550562311297215 delta 0.2840555726390118 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 13 (Topics 14 alpha_0 26.28722936026202 alpha_1 1.0 beta_0 0.007032529112731802 gamma 2.5706928156777993 delta 0.2748860814360708 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run
epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 75 (Topics 7 alpha_0 7.27730043811772 alpha_1 1.0 beta_0 0.0022345861709063505 gamma 2.9817886276038594 delta 0.10302619031945887 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 76 (Topics 7 alpha_0 7.250430729884242 alpha_1 1.0 beta_0 0.00223123154636111 gamma 2.9824222675863323 delta 0.10216167872068951 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 77 (Topics 7 alpha_0 7.224937035146667 alpha_1 1.0 beta_0 0.0022287379548642824 gamma 2.9864042784086737 delta 0.1013142875460326 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 78 (Topics 7 alpha_0 7.198786669595621 alpha_1 1.0 beta_0 0.0022262777514685857 gamma 2.987135613484603 delta 0.10049705242319748 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 79 (Topics 7 alpha_0 7.172401376941232 alpha_1 1.0 beta_0 0.0022198796534325786 gamma 2.989792598996597 delta 0.09969028687029347 epsilon 1.0
# ...................................................
# Storing variables...
# /home/c/work/topicmodels/food_test/ run 80 (Topics 7 alpha_0 7.147567677623773 alpha_1 1.0 beta_0 0.00221397584833521 gamma 2.9885165623778853 delta 0.09889355006259741 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 81 (Topics 7 alpha_0 7.123554920135515 alpha_1 1.0 beta_0 0.002208378758579203 gamma 2.991533241797041 delta 0.098128422095272 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 82 (Topics 6 alpha_0 7.0989901158388715 alpha_1 1.0 beta_0 0.0022024113976156297 gamma 2.9929602517315206 delta 0.09737216873061393 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 83 (Topics 6 alpha_0 7.0757155929756745 alpha_1 1.0 beta_0 0.002196023648136316 gamma 2.994550232260956 delta 0.09663387578048725 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 84 (Topics 6 alpha_0 7.052220626702359 alpha_1 1.0 beta_0 0.0021889699571227637 gamma 2.9961780401637896 delta 0.09591060211416401 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 85 (Topics 6 alpha_0 7.027973991977013 alpha_1 1.0 beta_0 0.0021857541837595282 gamma 2.9992934619007454 delta 0.09520924917652605 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 86 (Topics 6 alpha_0 7.004434435754547 alpha_1 1.0 beta_0 0.0021825475078400855 gamma 2.999351734532091 delta 0.09450807315337516 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 87 (Topics 6 alpha_0 6.981986039893389 alpha_1 1.0 beta_0 0.002180358417180362 gamma 3.0006444411256803 delta 0.09383929849418492 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 88 (Topics 6 alpha_0 6.960899419680041 alpha_1 1.0 beta_0 0.0021761161143335024 gamma 3.0035158128886645 delta 0.09317137487402853 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 89 (Topics 6 alpha_0 6.939741231747836 alpha_1 1.0 beta_0 0.0021755151214279357 gamma 3.003974545981385 delta 0.09252206040456648 epsilon 1.0
# ...................................................
# Storing variables...
# /home/c/work/topicmodels/food_test/ run 90 (Topics 6 alpha_0 6.917693848160503 alpha_1 1.0 beta_0 0.002173109726772292 gamma 3.0069196245993655 delta 0.09188989294958552 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 91 (Topics 6 alpha_0 6.896254192461204 alpha_1 1.0 beta_0 0.002173532634288686 gamma 3.0074760601503576 delta 0.0912645861183563 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 92 (Topics 6 alpha_0 6.8765109937319515 alpha_1 1.0 beta_0 0.0021710163173340896 gamma 3.007970693909935 delta 0.09065446044083561 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 93 (Topics 6 alpha_0 6.858332535902043 alpha_1 1.0 beta_0 0.002173328409057337 gamma 3.010741660256035 delta 0.0900605147030601 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 94 (Topics 6 alpha_0 6.838155645127319 alpha_1 1.0 beta_0 0.002172364581448124 gamma 3.0102141922891508 delta 0.0894761687889535 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 95 (Topics 6 alpha_0 6.819521612037131 alpha_1 1.0 beta_0 0.0021724819017796475 gamma 3.013560037439775 delta 0.08890475002058083 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 96 (Topics 6 alpha_0 6.801044552437976 alpha_1 1.0 beta_0 0.0021723090235256028 gamma 3.0137175520959953 delta 0.08833795595345595 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 97 (Topics 6 alpha_0 6.7817554706790375 alpha_1 1.0 beta_0 0.002171549591384681 gamma 3.0163347893420833 delta 0.08779675413711423 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 98 (Topics 6 alpha_0 6.7652613447848315 alpha_1 1.0 beta_0 0.002171496137059694 gamma 3.0182674848631894 delta 0.0872567796237622 epsilon 1.0
# ...................................................
# /home/c/work/topicmodels/food_test/ run 99 (Topics 6 alpha_0 6.746772589383248 alpha_1 1.0 beta_0 0.002171797590908237 gamma 3.018841392837976 delta 0.08673734339089616 epsilon 1.0
# ...................................................
# Storing variables...
# Perplexity: NaN
# opening folder /home/c/work/topicmodels/food_test//output_HMDP/100/clusters_0_geojson:
# processing topic_0.geojson ...
# processing topic_1.geojson ...
# processing topic_2.geojson ...
# processing topic_3.geojson ...
# processing topic_4.geojson ...
# processing topic_5.geojson ...
# processing topic_6.geojson ...
# processing topic_7.geojson ...
# processing topic_8.geojson ...
# processing topic_9.geojson ...
# processing topic_10.geojson ...
# processing topic_11.geojson ...
# processing topic_12.geojson ...
# processing topic_13.geojson ...
# processing topic_14.geojson ...
# processing topic_15.geojson ...
# processing topic_16.geojson ...
# processing topic_17.geojson ...
# processing topic_18.geojson ...
# processing topic_19.geojson ...
# processing topic_20.geojson ...
# processing topic_21.geojson ...
# processing topic_22.geojson ...
# processing topic_23.geojson ...
# processing topic_24.geojson ...
# created map in: /home/c/work/topicmodels/food_test//output_HMDP/100/clusters_0_geojson/topic_map.htm
# <a href="file:///home/c/work/topicmodels/food_test//output_HMDP/100/clusters_0_geojson/topic_map.htm" target="_blank">Link to map of clusters_0</a>

# %%
# %run 'hmdp.ipynb'

#directory of meta.txt and corpus.txt
directory = "/home/c/work/topicmodels/ml7_ordinal/";
#the first value in meta.txt are Geographical coordinates
#and we want to detect 1000 clusters
meta_params = "O";
#10 topics
T = 10;
#we only keep words which appear at least 2 times
MIN_DICT_WORDS = 2;
#run model

hmdp = HMDP(directory, meta_params);
hmdp.T = T;
hmdp.MIN_DICT_WORDS = 2;
hmdp.RUNS = 10;

#hmdp.run();

hmdp.plot_ordinal(0);

# %%
# %run 'hmdp.ipynb'
# %matplotlib inline

#directory of meta.txt and corpus.txt
directory = "/home/c/work/topicmodels/ml_test/";
#the first value in meta.txt are Geographical coordinates
#and we want to detect 1000 clusters
meta_params = "G(1000)";
#10 topics
T = 25;
#we only keep words which appear at least 2 times
MIN_DICT_WORDS = 2;
#run model

hmdp = HMDP(directory, meta_params);
hmdp.T = T;
hmdp.MIN_DICT_WORDS = 2;
hmdp.RUNS = 10;

#hmdp.run();

hmdp.plot_time(5);
